# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv(r"C:\Users\ROHAN SANJAY\Downloads\house_price.csv")
df.head()
# Out:
#    area  rooms   price
# 0  2104      3  399900
# 1  1600      3  329900
# 2  2400      3  369000
# 3  1416      2  232000
# 4  3000      4  539900

# %%
print(df.corr())
# Out:
#            area     rooms     price
# area   1.000000  0.559967  0.854988
# rooms  0.559967  1.000000  0.442261
# price  0.854988  0.442261  1.000000

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.title('House price prediction')
plt.scatter(df.area,df.price,marker="*",color="blue")

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[["area","rooms"]]
y=df[["price"]]
x_train,x_test,y_train,y_test= train_test_split(X,y,train_size=0.25)

# %%
model=linear_model.LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error,r2_score
predictss=model.predict(x_test)
r2=r2_score(y_test,predictss)
print(r2)
# Out:
# 0.6259548028239297

# %%
plt.xlabel("Area")
plt.ylabel("Price")
plt.title('House price prediction')
op=df[["area","rooms"]]
plt.scatter(df.area,df.price,marker="*",color="blue")
plt.plot(op,model.predict(op))

# %%
model.predict(x_test)
# Out:
# array([[352621.77636655],
#        [344088.79168113],
#        [440033.28911298],
#        [339544.82795423],
#        [259905.88474065],
#        [224271.64288232],
#        [228098.13865234],
#        [208009.03585972],
#        [248306.81943777],
#        [332532.67357393],
#        [302475.65018214],
#        [314954.70863039],
#        [250817.95728684],
#        [287767.55706612],
#        [241490.87384742],
#        [614181.79384466],
#        [436326.37133577],
#        [274331.87467536],
#        [219966.83514104],
#        [309573.6989538 ],
#        [451589.40722018],
#        [363460.42651686],
#        [301117.34506551],
#        [267798.03226632],
#        [244676.53245769],
#        [336120.01335833],
#        [391800.41081359],
#        [378527.25361132],
#        [295258.02341766],
#        [541631.6358085 ],
#        [177234.54451105],
#        [328065.34064416],
#        [384549.10044767],
#        [299050.83558624],
#        [294148.1378809 ],
# ...

# %%
print(x_test)
# Out:
#     area  rooms
# 15  2300      4
# 41  2238      3
# 19  3031      4
# 28  2200      3
# 6   1534      3
# 17  1236      3
# 14  1268      3
# 25  1100      3
# 35  1437      3
# 37  2132      4
# 12  1890      3
# 5   1985      4
# 26  1458      3
# 20  1767      3
# 8   1380      3
# 13  4478      5
# 4   3000      4
# 40  1664      2
# 43  1200      3
# 10  1940      4
# 33  3137      3
# 2   2400      3
# 21  1888      2
# 1   1600      3
# 3   1416      2
# 39  2162      4
# 29  2637      3
# 27  2526      3
# 30  1839      2
# 24  3890      3
# 44   852      2
# 0   2104      3
# 42  2567      4
# 45  1852      4
# 34  1811      4
# 11  2000      3

# %%
# the error in line fit can be even reduced by avoiding the smokers in the data
